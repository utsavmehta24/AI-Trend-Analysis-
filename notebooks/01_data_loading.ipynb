# %%
import pandas as pd

# %%
file_path = "../data/raw/google_trends_chatgpt_raw.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    2020-12-27  0
# 0  2021-01-03  0
# 1  2021-01-10  0
# 2  2021-01-17  0
# 3  2021-01-24  0
# 4  2021-01-31  0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   2020-12-27  261 non-null    object
#  1   0           261 non-null    object
# dtypes: object(2)
# memory usage: 4.2+ KB

# %%
df.isnull().sum()
# Out:
# 2020-12-27    0
# 0             0
# dtype: int64

# %%
df.shape
# Out:
# (261, 2)

# %%
df.to_csv("../data/processed/ai_trends_cleaned.csv", index=False)
